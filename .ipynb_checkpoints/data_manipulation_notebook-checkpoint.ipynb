# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import sqlite3

# %%
##Importing Relevant Data

imdb_title_basics_df = pd.read_csv("Data/imdb.title.basics.csv.gz")
imdb_title_ratings_df = pd.read_csv("Data/imdb.title.ratings.csv.gz")

movie_gross_df = pd.read_csv("Data/bom.movie_gross.csv.gz")

# %%
imdb_title_basics_df.head(3)
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
#
#    start_year  runtime_minutes              genres
# 0        2013            175.0  Action,Crime,Drama
# 1        2019            114.0     Biography,Drama
# 2        2018            122.0               Drama

# %%
imdb_title_basics_df.set_index('tconst', inplace=True)
imdb_title_basics_df.head()
# Out:
#                              primary_title              original_title  \
# tconst
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#            start_year  runtime_minutes                genres
# tconst
# tt0063540        2013            175.0    Action,Crime,Drama
# tt0066787        2019            114.0       Biography,Drama
# tt0069049        2018            122.0                 Drama
# tt0069204        2018              NaN          Comedy,Drama
# tt0100275        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_title_ratings_df.set_index('tconst', inplace=True)
imdb_title_ratings_df.head(3)
# Out:
#             averagerating  numvotes
# tconst
# tt10356526            8.3        31
# tt10384606            8.9       559
# tt1042974             6.4        20

# %%
movie_gross_df.head(3)
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010

# %%
##Joining IMDB Data Frames
imdb_joined_df = imdb_title_ratings_df.merge(imdb_title_basics_df, on='tconst', how='inner')
imdb_joined_df.head()
# Out:
#             averagerating  numvotes           primary_title  \
# tconst
# tt10356526            8.3        31        Laiye Je Yaarian
# tt10384606            8.9       559              Borderless
# tt1042974             6.4        20               Just Inès
# tt1043726             4.2     50352  The Legend of Hercules
# tt1060240             6.5        21               Até Onde?
#
#                     original_title  start_year  runtime_minutes  \
# tconst
# tt10356526        Laiye Je Yaarian        2019            117.0
# tt10384606              Borderless        2019             87.0
# tt1042974                Just Inès        2010             90.0
# tt1043726   The Legend of Hercules        2014             99.0
# tt1060240                Até Onde?        2011             73.0
#
#                               genres
# tconst
# tt10356526                   Romance
# tt10384606               Documentary
# tt1042974                      Drama
# tt1043726   Action,Adventure,Fantasy
# tt1060240           Mystery,Thriller

# %%
## Check to make sure this looks right (Using "Borderless" movie as an example)

imdb_title_basics_df.loc['tt10384606']
# Out:
# primary_title       Borderless
# original_title      Borderless
# start_year                2019
# runtime_minutes             87
# genres             Documentary
# Name: tt10384606, dtype: object

# %%
## All Good!

imdb_title_ratings_df.loc['tt10384606']
# Out:
# averagerating      8.9
# numvotes         559.0
# Name: tt10384606, dtype: float64

# %%
##How many titles were lost?

print("Joined table: ", len(imdb_joined_df))
print("Ratings table: ", len(imdb_title_ratings_df))
print("Basics table: ", len(imdb_title_basics_df))
# Out:
# Joined table:  73856
# Ratings table:  73856
# Basics table:  146144

# %%
## Are primary_title and original_title the same?

imdb_joined_df['primary_title'].equals(imdb_joined_df['original_title'])
# Out:
# False

# %%
## Which are different?
imdb_joined_df['Name Match?'] = imdb_joined_df.apply(lambda x:
                                                     True if x['primary_title'] == x['original_title'] else False, axis=1)

# %%
imdb_joined_df[imdb_joined_df['primary_title'] != imdb_joined_df['original_title']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12173 entries, tt1094666 to tt9844256
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   averagerating    12173 non-null  float64
#  1   numvotes         12173 non-null  int64
#  2   primary_title    12173 non-null  object
#  3   original_title   12173 non-null  object
#  4   start_year       12173 non-null  int64
#  5   runtime_minutes  11514 non-null  float64
#  6   genres           12092 non-null  object
#  7   Name Match?      12173 non-null  bool
# dtypes: bool(1), float64(2), int64(2), object(3)
# memory usage: 772.7+ KB

# %%
imdb_joined_df.loc[imdb_joined_df['Name Match?'] == False]
# Out:
#            averagerating  numvotes  \
# tconst
# tt1094666            7.0      1613
# tt1130982            6.4       571
# tt1156528            7.2       265
# tt1161457            4.2       148
# tt1181840            7.0      5494
# ...                  ...       ...
# tt9461680            5.2        20
# tt9526152            7.6        29
# tt9690762            5.6        37
# tt9691896            6.3        21
# tt9844256            7.5        24
#
#                                                primary_title  \
# tconst
# tt1094666                                         The Hammer
# tt1130982                                    The Night Clerk
# tt1156528                                      Silent Sonata
# tt1161457                                         Vanquisher
# tt1181840                    Jack and the Cuckoo-Clock Heart
# ...                                                      ...
# tt9461680              Nona: If They Soak Me, I'll Burn Them
# tt9526152  DanMachi: Is It Wrong to Try to Pick Up Girls ...
# tt9690762                                     On the Balcony
# tt9691896                                                Out
# tt9844256  Code Geass: Lelouch of the Rebellion - Glorifi...
#
#                                               original_title  start_year  \
# tconst
# tt1094666                                             Hamill        2010
# tt1130982                                       Avant l'aube        2011
# tt1156528                                 Circus Fantasticus        2011
# tt1161457                                     The Vanquisher        2016
# tt1181840                      Jack et la mécanique du coeur        2013
# ...                                                      ...         ...
# tt9461680                    Nona. Si me mojan, yo los quemo        2019
# tt9526152  Gekijouban danjon ni deai o motomeru no wa mac...        2019
# tt9690762                                     Yang tai shang        2019
# tt9691896                                         Coming Out        2018
# tt9844256   Code Geass: Lelouch of the Rebellion Episode III        2018
#
#            runtime_minutes                      genres  Name Match?
# tconst
# tt1094666            108.0       Biography,Drama,Sport        False
# tt1130982            104.0              Drama,Thriller        False
# tt1156528             77.0                   Drama,War        False
# tt1161457             90.0     Action,Adventure,Sci-Fi        False
# tt1181840             94.0   Adventure,Animation,Drama        False
# ...                    ...                         ...          ...
# tt9461680             86.0                     Fantasy        False
# tt9526152             82.0  Action,Adventure,Animation        False
# tt9690762            100.0                       Drama        False
# tt9691896             64.0                 Documentary        False
# tt9844256            120.0     Action,Animation,Sci-Fi        False
#
# [12173 rows x 8 columns]

# %%
len(imdb_joined_df)
# Out:
# 73856

# %%
##Now let's go back to our revenue table
movie_gross_df.head(3)
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010

# %%
##Can we join these tables on name?
movie_gross_df.loc[movie_gross_df['title'] == 'Jack and the Cuckoo-Clock Heart']
# Out:
#                                 title  studio  domestic_gross foreign_gross  \
# 1685  Jack and the Cuckoo-Clock Heart  Shout!             NaN       3400000
#
#       year
# 1685  2014

# %%
##We should be joining on primary title

joined_df = movie_gross_df.merge(imdb_joined_df, left_on = 'title', right_on='primary_title', how='inner')

joined_df.head(3)
# Out:
#                  title studio  domestic_gross foreign_gross  year  \
# 0          Toy Story 3     BV     415000000.0     652000000  2010
# 1            Inception     WB     292600000.0     535700000  2010
# 2  Shrek Forever After   P/DW     238700000.0     513900000  2010
#
#    averagerating  numvotes        primary_title       original_title  \
# 0            8.3    682218          Toy Story 3          Toy Story 3
# 1            8.8   1841066            Inception            Inception
# 2            6.3    167532  Shrek Forever After  Shrek Forever After
#
#    start_year  runtime_minutes                      genres  Name Match?
# 0        2010            103.0  Adventure,Animation,Comedy         True
# 1        2010            148.0     Action,Adventure,Sci-Fi         True
# 2        2010             93.0  Adventure,Animation,Comedy         True

# %%
## Let's do some checking

print("Joined table: ", len(joined_df))
print("IMDB table: ", len(imdb_joined_df))
print("Revenue table: ", len(movie_gross_df))
# Out:
# Joined table:  3027
# IMDB table:  73856
# Revenue table:  3387

# %%
joined_df.drop(columns='primary_title', inplace=True)
joined_df.set_index('title', inplace=True)
#joined_df.head(3)

# %%
## Let's check some basic correlations

joined_df.corr()
# Out:
#                  domestic_gross      year  averagerating  numvotes  \
# domestic_gross         1.000000  0.008786       0.119300  0.664384
# year                   0.008786  1.000000       0.040499 -0.121836
# averagerating          0.119300  0.040499       1.000000  0.278394
# numvotes               0.664384 -0.121836       0.278394  1.000000
# start_year             0.037069  0.808273      -0.004172 -0.078001
# runtime_minutes        0.126917  0.033626       0.151125  0.260232
# Name Match?            0.172891 -0.074166      -0.092221  0.190484
#
#                  start_year  runtime_minutes  Name Match?
# domestic_gross     0.037069         0.126917     0.172891
# year               0.808273         0.033626    -0.074166
# averagerating     -0.004172         0.151125    -0.092221
# numvotes          -0.078001         0.260232     0.190484
# start_year         1.000000         0.080132    -0.016238
# runtime_minutes    0.080132         1.000000    -0.034410
# Name Match?       -0.016238        -0.034410     1.000000

# %%
## Whoops! First we need foreign gross in an integer
joined_df['foreign_gross'].isnull().sum()

joined_df['foreign_gross'] = pd.to_numeric(joined_df['foreign_gross'], errors='coerce')

# %%
joined_df['foreign_gross'].isnull().sum()
# Out:
# 1199

# %%
joined_df.corr()
# Out:
#                  domestic_gross  foreign_gross      year  averagerating  \
# domestic_gross         1.000000       0.827830  0.008786       0.119300
# foreign_gross          0.827830       1.000000  0.129775       0.153432
# year                   0.008786       0.129775  1.000000       0.040499
# averagerating          0.119300       0.153432  0.040499       1.000000
# numvotes               0.664384       0.559610 -0.121836       0.278394
# start_year             0.037069       0.121749  0.808273      -0.004172
# runtime_minutes        0.126917       0.195664  0.033626       0.151125
# Name Match?            0.172891       0.070176 -0.074166      -0.092221
#
#                  numvotes  start_year  runtime_minutes  Name Match?
# domestic_gross   0.664384    0.037069         0.126917     0.172891
# foreign_gross    0.559610    0.121749         0.195664     0.070176
# year            -0.121836    0.808273         0.033626    -0.074166
# averagerating    0.278394   -0.004172         0.151125    -0.092221
# numvotes         1.000000   -0.078001         0.260232     0.190484
# start_year      -0.078001    1.000000         0.080132    -0.016238
# runtime_minutes  0.260232    0.080132         1.000000    -0.034410
# Name Match?      0.190484   -0.016238        -0.034410     1.000000

# %%
joined_df['genres'].isnull().sum()
# Out:
# 7

# %%
joined_df.dropna(subset=['genres'], inplace=True)

# %%
joined_df['genres'].isnull().sum()
# Out:
# 0

# %%
joined_df.head()
# Out:
#                            studio  domestic_gross  foreign_gross  year  \
# title
# Toy Story 3                    BV     415000000.0    652000000.0  2010
# Inception                      WB     292600000.0    535700000.0  2010
# Shrek Forever After          P/DW     238700000.0    513900000.0  2010
# The Twilight Saga: Eclipse   Sum.     300500000.0    398000000.0  2010
# Iron Man 2                   Par.     312400000.0    311500000.0  2010
#
#                             averagerating  numvotes  \
# title
# Toy Story 3                           8.3    682218
# Inception                             8.8   1841066
# Shrek Forever After                   6.3    167532
# The Twilight Saga: Eclipse            5.0    211733
# Iron Man 2                            7.0    657690
#
#                                         original_title  start_year  \
# title
# Toy Story 3                                Toy Story 3        2010
# Inception                                    Inception        2010
# Shrek Forever After                Shrek Forever After        2010
# The Twilight Saga: Eclipse  The Twilight Saga: Eclipse        2010
# Iron Man 2                                  Iron Man 2        2010
#
#                             runtime_minutes                      genres  \
# title
# Toy Story 3                           103.0  Adventure,Animation,Comedy
# Inception                             148.0     Action,Adventure,Sci-Fi
# Shrek Forever After                    93.0  Adventure,Animation,Comedy
# The Twilight Saga: Eclipse            124.0     Adventure,Drama,Fantasy
# Iron Man 2                            124.0     Action,Adventure,Sci-Fi
#
#                             Name Match?
# title
# Toy Story 3                        True
# Inception                          True
# Shrek Forever After                True
# The Twilight Saga: Eclipse         True
# Iron Man 2                         True

# %%
## Let's split Genres into different columns

genres_df = joined_df['genres'].str.split(',', expand=True)
genres_df.head()
# Out:
#                                     0          1        2
# title
# Toy Story 3                 Adventure  Animation   Comedy
# Inception                      Action  Adventure   Sci-Fi
# Shrek Forever After         Adventure  Animation   Comedy
# The Twilight Saga: Eclipse  Adventure      Drama  Fantasy
# Iron Man 2                     Action  Adventure   Sci-Fi

# %%
joined_df['Genre 1'] = genres_df[0]
joined_df['Genre 2'] = genres_df[1]
joined_df['Genre 3'] = genres_df[2]

joined_df.head(3)
# Out:
#                     studio  domestic_gross  foreign_gross  year  \
# title
# Toy Story 3             BV     415000000.0    652000000.0  2010
# Inception               WB     292600000.0    535700000.0  2010
# Shrek Forever After   P/DW     238700000.0    513900000.0  2010
#
#                      averagerating  numvotes       original_title  start_year  \
# title
# Toy Story 3                    8.3    682218          Toy Story 3        2010
# Inception                      8.8   1841066            Inception        2010
# Shrek Forever After            6.3    167532  Shrek Forever After        2010
#
#                      runtime_minutes                      genres  Name Match?  \
# title
# Toy Story 3                    103.0  Adventure,Animation,Comedy         True
# Inception                      148.0     Action,Adventure,Sci-Fi         True
# Shrek Forever After             93.0  Adventure,Animation,Comedy         True
#
#                        Genre 1    Genre 2 Genre 3
# title
# Toy Story 3          Adventure  Animation  Comedy
# Inception               Action  Adventure  Sci-Fi
# Shrek Forever After  Adventure  Animation  Comedy

# %%
joined_df.drop(columns=['Name Match?'], inplace=True)
joined_df.head(3)
# Out:
#                     studio  domestic_gross  foreign_gross  year  \
# title
# Toy Story 3             BV     415000000.0    652000000.0  2010
# Inception               WB     292600000.0    535700000.0  2010
# Shrek Forever After   P/DW     238700000.0    513900000.0  2010
#
#                      averagerating  numvotes       original_title  start_year  \
# title
# Toy Story 3                    8.3    682218          Toy Story 3        2010
# Inception                      8.8   1841066            Inception        2010
# Shrek Forever After            6.3    167532  Shrek Forever After        2010
#
#                      runtime_minutes                      genres    Genre 1  \
# title
# Toy Story 3                    103.0  Adventure,Animation,Comedy  Adventure
# Inception                      148.0     Action,Adventure,Sci-Fi     Action
# Shrek Forever After             93.0  Adventure,Animation,Comedy  Adventure
#
#                        Genre 2 Genre 3
# title
# Toy Story 3          Animation  Comedy
# Inception            Adventure  Sci-Fi
# Shrek Forever After  Animation  Comedy

# %%
genre_list = list(joined_df['Genre 1'].unique())
print(genre_list)
# Out:
# ['Adventure', 'Action', 'Animation', 'Biography', 'Drama', 'Comedy', 'Mystery', 'Thriller', 'Horror', 'Documentary', 'Crime', 'Family', 'Romance', 'Fantasy', 'Sport', 'Music', 'Sci-Fi']

# %%
combinations_list = joined_df['genres'].unique()
print(combinations_list)
# Out:
# ['Adventure,Animation,Comedy' 'Action,Adventure,Sci-Fi'
#  'Adventure,Drama,Fantasy' 'Animation,Comedy,Family'
#  'Action,Adventure,Animation' 'Adventure,Family,Fantasy'
#  'Biography,Drama,History' 'Action,Drama,Family'
#  'Action,Adventure,Fantasy' 'Drama,Thriller' 'Action,Animation,Comedy'
#  'Action,Drama' 'Action,Adventure,Thriller' 'Action,Adventure,Drama'
#  'Action,Adventure,Family' 'Comedy,Romance' 'Action,Adventure,Horror'
#  'Mystery,Thriller' 'Action,Mystery,Thriller' 'Comedy,Drama,Romance'
#  'Comedy' 'Adventure,Drama,Western' 'Adventure,Comedy,Family'
#  'Biography,Drama' 'Adventure,Comedy' 'Drama,Romance' 'Drama' 'Thriller'
#  'Horror' 'Action,Comedy,Crime' 'Action,Thriller' 'Action,Crime'
#  'Documentary' 'Crime,Drama,Thriller' 'Comedy,Crime,Romance'
#  'Drama,Fantasy,Horror' 'Action,Comedy,Romance' 'Biography,Drama,Sport'
#  'Drama,Romance,War' 'Action,Comedy,Family' 'Comedy,Family,Fantasy'
#  'Drama,Fantasy,Romance' 'Crime,Drama,Mystery' 'Action,Crime,Drama'
#  'Action,Comedy' 'Action,Drama,Thriller' 'Adventure,Comedy,Music'
#  'Drama,Music,Musical' 'Drama,Music,Romance' 'Comedy,Family'
#  'Comedy,Horror' 'Adventure,Comedy,Drama' 'Comedy,Drama,Family'
#  'Action,Crime,Thriller' 'Drama,Horror,Thriller' 'Action,Sci-Fi,Thriller'
#  'Comedy,Sci-Fi' 'Horror,Mystery,Thriller' 'Adventure,Biography,Drama'
#  'Biography,Drama,Family' 'Drama,Mystery,Thriller' 'Horror,Thriller'
#  'Action,Comedy,Fantasy' 'Comedy,Family,Romance' 'Action,Adventure,Crime'
#  'Comedy,Romance,Sport' 'Drama,Music' 'Comedy,Drama' 'Action,Crime,Sci-Fi'
#  'Action,Family,Fantasy' 'Drama,Mystery' 'Crime,Drama'
#  'Biography,Comedy,Drama' 'Action,Fantasy,Western' 'Action,Drama,Fantasy'
#  'Crime,Horror,Mystery' 'Biography,Crime,Drama' 'Drama,Romance,Sci-Fi'
#  'Crime,Documentary' 'Biography,Documentary' 'Comedy,Crime,Documentary'
#  'Biography,Drama,Music' 'Adventure' 'Comedy,Crime,Drama'
#  'Drama,Sci-Fi,Thriller' 'Adventure,Fantasy,Horror' 'Crime,Drama,Horror'
#  'Documentary,Drama,Mystery' 'Action,Drama,Romance' 'Drama,Family'
#  'Family,Sport' 'Comedy,Crime' 'Family' 'Comedy,Drama,Musical'
#  'Documentary,War' 'Comedy,Drama,Fantasy' 'Biography,Drama,Romance'
#  'Action,Fantasy,Horror' 'Biography,Comedy,Crime' 'Drama,Romance,Thriller'
#  'Comedy,Drama,Music' 'Thriller,Western' 'Documentary,History'
#  'Documentary,Music' 'Crime,Thriller' 'Comedy,Mystery'
#  'Action,Drama,Sci-Fi' 'Mystery,Sci-Fi,Thriller' 'Adventure,Drama,Family'
#  'Drama,History,War' 'Action,Adventure,Comedy' 'Comedy,Fantasy,Romance'
#  'Romance,Sci-Fi,Thriller' 'Adventure,Drama,Thriller'
#  'Adventure,Comedy,Sci-Fi' 'Horror,Mystery' 'Drama,Horror,Mystery'
#  'Fantasy,Horror,Mystery' 'Action,Sci-Fi' 'Action,Comedy,Drama'
#  'Comedy,Fantasy' 'Documentary,News' 'Drama,Fantasy' 'Drama,History'
#  'Adventure,Drama,Mystery' 'Action' 'Adventure,Animation,Family'
#  'Fantasy,Horror,Thriller' 'Adventure,Documentary'
#  'Action,Fantasy,Thriller' 'Action,Drama,History' 'Horror,Mystery,Sci-Fi'
#  'Adventure,Comedy,Fantasy' 'Drama,Sport' 'Drama,War'
#  'Adventure,Drama,History' 'Documentary,Drama,Family'
#  'Comedy,Crime,Thriller' 'Animation,Comedy,Crime' 'Drama,Sci-Fi'
#  'Drama,Mystery,Romance' 'Crime,Drama,History' 'Horror,Romance'
#  'Comedy,Drama,Sport' 'Adventure,Comedy,Western'
#  'Crime,Documentary,History' 'Biography,Documentary,Sport'
#  'Action,Comedy,Sci-Fi' 'Comedy,Crime,History' 'Crime,Drama,Romance'
#  'Comedy,Drama,Mystery' 'Action,Biography,Crime' 'Comedy,Drama,Horror'
#  'Comedy,Crime,Mystery' 'Animation,Drama' 'Biography,Drama,Thriller'
#  'Action,Crime,Horror' 'Biography,Drama,War' 'Drama,Western'
#  'Action,Adventure,Western' 'Comedy,Mystery,Romance' 'Documentary,Drama'
#  'Crime,Documentary,Drama' 'Documentary,Musical' 'Romance,Thriller'
#  'Biography,Documentary,Drama' 'Comedy,Fantasy,Horror'
#  'Action,Documentary,History' 'Drama,Horror,Sci-Fi' 'Action,Drama,War'
#  'Adventure,Drama' 'Adventure,Mystery,Sci-Fi' 'Action,Horror,Sci-Fi'
#  'Drama,History,Thriller' 'Action,Drama,Mystery' 'Comedy,Music,Romance'
#  'Action,Comedy,Western' 'Action,Comedy,Sport' 'Action,Comedy,Horror'
#  'Fantasy,Romance' 'Action,Crime,Mystery' 'Crime,Mystery,Thriller'
#  'Action,History' 'Adventure,Drama,Romance' 'Drama,History,Romance'
#  'Action,Horror,Thriller' 'Sport' 'Drama,Mystery,Western'
#  'Drama,Fantasy,Thriller' 'Animation,Comedy,Fantasy'
#  'Biography,Documentary,Music' 'Comedy,Mystery,Thriller'
#  'Action,Romance,Thriller' 'Animation,Crime,Drama'
#  'Biography,Crime,Documentary' 'Action,Comedy,Musical' 'Animation,Fantasy'
#  'Fantasy' 'Drama,Thriller,War' 'Drama,Mystery,Sci-Fi'
#  'Action,Horror,Mystery' 'Action,Adventure' 'Comedy,Family,Sci-Fi'
#  'Romance' 'Adventure,Comedy,Crime' 'Biography,Documentary,History'
#  'Comedy,Musical,Romance' 'Fantasy,Mystery,Romance' 'Adventure,Family'
#  'Horror,Sci-Fi,Thriller' 'Action,Drama,Horror' 'Drama,Horror'
#  'Adventure,Drama,Sport' 'Adventure,Fantasy' 'Action,Biography,Drama'
#  'Comedy,Horror,Romance' 'Animation,Drama,Family' 'Comedy,Documentary'
#  'Adventure,History' 'Mystery' 'Biography,Comedy' 'Music'
#  'Drama,Family,Music' 'Action,Fantasy,Romance' 'Documentary,Drama,Sport'
#  'Drama,Sport,Thriller' 'Horror,Romance,Thriller' 'Adventure,Thriller'
#  'Biography,Documentary,Family' 'Documentary,History,News'
#  'Adventure,Drama,Sci-Fi' 'Animation' 'Action,Mystery,Sci-Fi'
#  'Action,Adventure,Mystery' 'Comedy,Musical' 'Action,Sport,War'
#  'Comedy,Drama,History' 'Animation,Biography,Drama' 'Comedy,Western'
#  'Drama,Fantasy,Music' 'Action,Animation,Drama' 'Adventure,Family,Sci-Fi'
#  'Drama,Fantasy,Mystery' 'Drama,Family,Sport' 'Adventure,Animation,Drama'
#  'Crime,Drama,Fantasy' 'Action,History,Thriller'
#  'Biography,Documentary,Thriller' 'Documentary,Drama,Music'
#  'Biography,Documentary,Mystery' 'Drama,Musical,Romance' 'Comedy,Thriller'
#  'Action,Animation' 'Animation,Drama,Sci-Fi' 'Adventure,Crime,Drama'
#  'Biography,Drama,Fantasy' 'Crime,Romance,Thriller'
#  'Biography,Comedy,Documentary' 'Action,Romance' 'Animation,Family'
#  'Action,Horror' 'Documentary,History,Thriller' 'Biography'
#  'Crime,Horror,Thriller' 'Action,Adventure,Biography' 'Comedy,Music'
#  'Adventure,Biography,Comedy' 'Comedy,Drama,Thriller' 'Fantasy,Horror'
#  'Comedy,Mystery,Sci-Fi' 'Mystery,Romance,Thriller' 'Adventure,Horror'
#  'Animation,Comedy,Drama' 'Adventure,Western' 'Action,Biography,History'
#  'Animation,Comedy,Music' 'Action,Animation,Sci-Fi' 'Crime,Mystery'
#  'Documentary,Drama,News' 'Drama,Fantasy,Sci-Fi' 'Drama,War,Western'
#  'Action,Drama,Sport' 'Adventure,Comedy,Romance' 'Animation,Drama,Fantasy'
#  'Action,Animation,Crime' 'Horror,Music,Thriller'
#  'Adventure,Documentary,Sport' 'Biography,History,Thriller'
#  'Comedy,Drama,War' 'Action,Drama,Western' 'Comedy,History'
#  'Documentary,Mystery' 'Comedy,Horror,Thriller' 'Comedy,Documentary,Drama'
#  'Action,Fantasy' 'Crime,Drama,War' 'Adventure,Comedy,History' 'Crime'
#  'Fantasy,Romance,Thriller' 'Adventure,Biography,Documentary' 'Sci-Fi'
#  'Biography,Drama,Musical' 'Action,Comedy,Thriller'
#  'Action,Biography,Comedy' 'Action,Comedy,War' 'Adventure,Drama,Horror'
#  'Animation,Biography,Crime' 'Drama,History,Sport' 'Documentary,Family'
#  'Action,Sport' 'Documentary,Drama,History' 'Animation,Drama,Romance'
#  'Animation,Drama,History' 'Action,Drama,Music' 'Comedy,Crime,Horror'
#  'Action,Comedy,Mystery' 'Adventure,Comedy,Horror' 'Comedy,Sport'
#  'Documentary,History,War' 'Documentary,Sport' 'Fantasy,Thriller'
#  'Documentary,Drama,Romance']

# %%
## Let's actually make these into columns with True/False values so we can see the correlation

for genre in genre_list:
    joined_df[genre] = joined_df['genres'].map(lambda x: genre in x)

joined_df.head()


## Number of genres vs performance -- do more genres corr w better performance 

## Distribution of genres
# Out:
#                            studio  domestic_gross  foreign_gross  year  \
# title
# Toy Story 3                    BV     415000000.0    652000000.0  2010
# Inception                      WB     292600000.0    535700000.0  2010
# Shrek Forever After          P/DW     238700000.0    513900000.0  2010
# The Twilight Saga: Eclipse   Sum.     300500000.0    398000000.0  2010
# Iron Man 2                   Par.     312400000.0    311500000.0  2010
#
#                             averagerating  numvotes  \
# title
# Toy Story 3                           8.3    682218
# Inception                             8.8   1841066
# Shrek Forever After                   6.3    167532
# The Twilight Saga: Eclipse            5.0    211733
# Iron Man 2                            7.0    657690
#
#                                         original_title  start_year  \
# title
# Toy Story 3                                Toy Story 3        2010
# Inception                                    Inception        2010
# Shrek Forever After                Shrek Forever After        2010
# The Twilight Saga: Eclipse  The Twilight Saga: Eclipse        2010
# Iron Man 2                                  Iron Man 2        2010
#
#                             runtime_minutes                      genres  ...  \
# title                                                                    ...
# Toy Story 3                           103.0  Adventure,Animation,Comedy  ...
# Inception                             148.0     Action,Adventure,Sci-Fi  ...
# Shrek Forever After                    93.0  Adventure,Animation,Comedy  ...
# The Twilight Saga: Eclipse            124.0     Adventure,Drama,Fantasy  ...
# Iron Man 2                            124.0     Action,Adventure,Sci-Fi  ...
#
#                            Thriller Horror Documentary  Crime  Family  \
# title
# Toy Story 3                   False  False       False  False   False
# Inception                     False  False       False  False   False
# Shrek Forever After           False  False       False  False   False
# The Twilight Saga: Eclipse    False  False       False  False   False
# Iron Man 2                    False  False       False  False   False
#
#                             Romance  Fantasy  Sport  Music  Sci-Fi
# title
# Toy Story 3                   False    False  False  False   False
# Inception                     False    False  False  False    True
# Shrek Forever After           False    False  False  False   False
# The Twilight Saga: Eclipse    False     True  False  False   False
# Iron Man 2                    False    False  False  False    True
#
# [5 rows x 30 columns]

# %%
boxplot_df = joined_df.loc[:, ['domestic_gross', 'genres', 'domestic_gross_win']]

# %%
joined_df.corr()
# Out:
#                  domestic_gross  foreign_gross      year  averagerating  \
# domestic_gross         1.000000       0.827783  0.009248       0.119377
# foreign_gross          0.827783       1.000000  0.130427       0.152904
# year                   0.009248       0.130427  1.000000       0.040425
# averagerating          0.119377       0.152904  0.040425       1.000000
# numvotes               0.665179       0.560130 -0.122952       0.278443
# Sport           -0.000697 -0.015423 -0.032642  1.000000 -0.025615 -0.028912
# Music           -0.029194 -0.007828 -0.039037 -0.025615  1.000000 -0.041459
# Sci-Fi          -0.026821 -0.057212 -0.045880 -0.028912 -0.041459  1.000000
#
# [24 rows x 24 columns]

# %%
joined_df.describe()
# Out:
#        domestic_gross  foreign_gross         year  averagerating  \
# count    2.998000e+03   1.821000e+03  3020.000000    3020.000000
# mean     3.059426e+07   7.847187e+07  2014.081788       6.458543
# std      6.676743e+07   1.388996e+08     2.440195       1.011853
# min      1.000000e+02   6.000000e+02  2010.000000       1.600000
# 25%      1.380000e+05   4.700000e+06  2012.000000       5.900000
# 50%      2.000000e+06   2.120000e+07  2014.000000       6.600000
# 75%      3.240000e+07   8.170000e+07  2016.000000       7.100000
# max      7.001000e+08   9.464000e+08  2018.000000       9.200000
#
#            numvotes   start_year  runtime_minutes
# count  3.020000e+03  3020.000000      2975.000000
# mean   6.184327e+04  2013.784437       107.257815
# std    1.256234e+05     2.464499        20.048405
# min    5.000000e+00  2010.000000         3.000000
# 25%    2.199000e+03  2012.000000        94.000000
# 50%    1.324900e+04  2014.000000       105.000000
# 75%    6.319075e+04  2016.000000       118.000000
# max    1.841066e+06  2019.000000       272.000000

# %%
## Let's graph this

fig, ax = plt.subplots(figsize=(20,6))

sns.boxplot(x='Genre 1', y='domestic_gross', data=joined_df)
# Out:
# <AxesSubplot:xlabel='Genre 1', ylabel='domestic_gross'>

# %%
## Action genre

from scipy.stats import mstats

x_new = mstats.winsorize(joined_df['domestic_gross'], limits=[0, 0.05])




x = joined_df[joined_df['Action'] == True]['domestic_gross']


plt.hist(x=x_new, bins=100);

# %%
joined_df['domestic_gross_win'] = x_new
joined_df['domestic_gross_win']
# Out:
# title
# Toy Story 3                   163000000.0
# Inception                     163000000.0
# Shrek Forever After           163000000.0
# The Twilight Saga: Eclipse    163000000.0
# Iron Man 2                    163000000.0
#                                  ...
# Souvenir                          11400.0
# Souvenir                          11400.0
# Beauty and the Dogs                8900.0
# The Quake                          6200.0
# An Actor Prepares                  1700.0
# Name: domestic_gross_win, Length: 3020, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20,6))

sns.boxplot(x='Genre 1', y='domestic_gross_win', data=joined_df)
# Out:
# <AxesSubplot:xlabel='Genre 1', ylabel='domestic_gross_win'>

# %%
## Time to combine total revenue
joined_df['gross_total'] = joined_df['domestic_gross'] + joined_df['foreign_gross']

# %%
joined_df.corr()
# Out:
#                  domestic_gross  foreign_gross      year  averagerating  \
# domestic_gross         1.000000       0.827783  0.009248       0.119377
# foreign_gross          0.827783       1.000000  0.130427       0.152904
# year                   0.009248       0.130427  1.000000       0.040425
# averagerating          0.119377       0.152904  0.040425       1.000000
# numvotes               0.665179       0.560130 -0.122952       0.278443
# start_year             0.037081       0.121540  0.811323      -0.004315
# runtime_minutes        0.127532       0.195690  0.033309       0.151515
# Adventure              0.401188       0.481695  0.038157       0.008078
# Action                 0.225222       0.287781  0.004357      -0.094519
# Animation              0.199909       0.246443  0.038841       0.054945
# Biography             -0.048898      -0.074087  0.084813       0.164259
# Sci-Fi          -0.057212 -0.045880 -0.028912 -0.041459  1.000000     0.256073
# gross_total     -0.130354  0.113181 -0.003070 -0.039465  0.256073     1.000000
#
# [25 rows x 25 columns]

# %%
movie_info_df = pd.read_csv("Data/tmdb.movies.csv.gz")

# %%
movie_info_df.head(3)
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368

# %%
boxplot_df = joined_df.loc[:, ['domestic_gross', 'genres', 'domestic_gross_win']]

# %%
boxplot_df.head(3)
# Out:
#                      domestic_gross                      genres  \
# title
# Toy Story 3             415000000.0  Adventure,Animation,Comedy
# Inception               292600000.0     Action,Adventure,Sci-Fi
# Shrek Forever After     238700000.0  Adventure,Animation,Comedy
#
#                      domestic_gross_win
# title
# Toy Story 3                 163000000.0
# Inception                   163000000.0
# Shrek Forever After         163000000.0

# %%
for genre in genre_list:
    boxplot_df[genre] = boxplot_df['genres'].map(lambda x: boxplot_df['domestic_gross'] if genre in x else False)

boxplot_df.head(3)


# for genre in genre_list:
#     joined_df[genre] = joined_df['genres'].map(lambda x: genre in x)
# Out:
#                      domestic_gross                      genres  \
# title
# Toy Story 3             415000000.0  Adventure,Animation,Comedy
# Inception               292600000.0     Action,Adventure,Sci-Fi
# Shrek Forever After     238700000.0  Adventure,Animation,Comedy
#
#                      domestic_gross_win  \
# title
# Toy Story 3                 163000000.0
# Inception                   163000000.0
# Shrek Forever After         163000000.0
#
#                                                              Adventure  \
# title
# Toy Story 3          title
# Toy Story 3                   415000000....
# Inception            title
# Toy Story 3                   415000000....
# Shrek Forever After  title
# Toy Story 3                   415000000....
#
#                                                                 Action  \
# title
# Toy Story 3                                                      False
# Inception            title
# Toy Story 3                   415000000....
# Shrek Forever After                                              False
#
#                                                              Animation  \
# title
# Toy Story 3          title
# Toy Story 3                   415000000....
# Inception                                                        False
# Shrek Forever After  title
# Toy Story 3                   415000000....
#
#                     Biography  Drama  \
# title
# Toy Story 3             False  False
# Inception               False  False
# Shrek Forever After     False  False
#
#                                                                 Comedy  \
# title
# Toy Story 3          title
# Toy Story 3                   415000000....
# Inception                                                        False
# Shrek Forever After  title
# Toy Story 3                   415000000....
#
#                     Mystery Thriller Horror Documentary  Crime Family Romance  \
# title
# Toy Story 3           False    False  False       False  False  False   False
# Inception             False    False  False       False  False  False   False
# Shrek Forever After   False    False  False       False  False  False   False
#
#                     Fantasy  Sport  Music  \
# title
# Toy Story 3           False  False  False
# Inception             False  False  False
# Shrek Forever After   False  False  False
#
#                                                                 Sci-Fi
# title
# Toy Story 3                                                      False
# Inception            title
# Toy Story 3                   415000000....
# Shrek Forever After                                              False

# %%
fig, ax = plt.subplots(figsize=(20,6))

sns.boxplot(x='Genre 1', y='domestic_gross_win', data=joined_df)

# %% [markdown]
# -Looking at the number of genres
# -Looking at distribution of genres : what the most common genres are
# -Looking at distribution of values in general
#
# -Scatterplot w line of bestfit & R^2
# -Mess around w winsorization
